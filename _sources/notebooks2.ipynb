# %% [markdown]
# # Tugas 2 - Diskritisasi

# %% [markdown]
# 1. mencari nilai equel width
# 2. mencari nilai equel frekuensi
# 3. entropy

# %% [markdown]
# ## Equel Width

# %% [markdown]
# rumus
# $$ w=\frac{x_{min}-x_{max}}k $$
#
# $$v_i=x_{min}+i*w$$
#
# dimana i = 1,2,3,..k

# %%
# import library
import pandas as pd
import math
from sklearn import datasets

# %%
# membaca dataset
dt_iris = pd.read_csv("https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv")
print(dt_iris)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
dt_iris.head(10)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa
# 6           4.6          3.4           1.4          0.3  Setosa
# 7           5.0          3.4           1.5          0.2  Setosa
# 8           4.4          2.9           1.4          0.2  Setosa
# 9           4.9          3.1           1.5          0.1  Setosa

# %%
# CONSTAN SERIES

SEPAL_LENGTH_SERIES = dt_iris["sepal.length"]
SEPAL_WIDTH_SERIES = dt_iris["sepal.width"]
PETAL_LENGTH_SERIES = dt_iris["petal.length"]
PETAL_WIDTH_SERIES = dt_iris["petal.width"]

# %%
# equal-width intervals

labels = ["A", "B"]
amount_of_binning = len(labels)

sepal_width_ew_binning = pd.cut(SEPAL_WIDTH_SERIES, amount_of_binning, True, labels)
labelled_sepal_width_ew_binning = sepal_width_ew_binning.value_counts()
interval_sepal_width_ew_binning = pd.cut(SEPAL_WIDTH_SERIES, amount_of_binning, True).value_counts()

# %%
# dataframe of sepal-width and sepal category
pd.concat((SEPAL_WIDTH_SERIES, sepal_width_ew_binning), axis=1)
# Out:
#     sepal.width sepal.width
# 0           2.0           B
# 1           1.0           A
# 2           2.0           B
# 3           1.0           A
# 4           2.0           B
# ..          ...         ...
# 145         1.0           A
# 146         0.0           A
# 147         1.0           A
# 148         2.0           B
# 149         1.0           A
#
# [150 rows x 2 columns]

# %%
# equal-width intervals binning with label
labelled_sepal_width_ew_binning
# Out:
# A    94
# B    56
# Name: sepal.width, dtype: int64

# %%
# equal-width intervals without label
interval_sepal_width_ew_binning
# Out:
# (-0.003, 1.5]    94
# (1.5, 3.0]       56
# Name: sepal.width, dtype: int64

# %%
# equal-width intervals

labels = ["A", "B"]
amount_of_binning = len(labels)

sepal_width_ew_binning = pd.cut(SEPAL_LENGTH_SERIES, amount_of_binning, True, labels)
labelled_sepal_width_ew_binning = sepal_width_ew_binning.value_counts()
interval_sepal_width_ew_binning = pd.cut(SEPAL_LENGTH_SERIES, amount_of_binning, True).value_counts()

# %%
# dataframe of sepal-length and sepal category
pd.concat((SEPAL_LENGTH_SERIES, sepal_width_ew_binning), axis=1)
# Out:
#     sepal.length sepal.length
# 0            0.0            A
# 1            0.0            A
# 2            0.0            A
# 3            0.0            A
# 4            0.0            A
# ..           ...          ...
# 145          2.0            B
# 146          2.0            B
# 147          2.0            B
# 148          2.0            B
# 149          1.0            A
#
# [150 rows x 2 columns]

# %%
# equal-width intervals binning with label
labelled_sepal_width_ew_binning
# Out:
# A    89
# B    61
# Name: sepal.length, dtype: int64

# %%
# equal-width intervals without label
interval_sepal_width_ew_binning
# Out:
# (-0.003, 1.5]    89
# (1.5, 3.0]       61
# Name: sepal.length, dtype: int64

# %%
# equal-width intervals

labels = ["A", "B"]
amount_of_binning = len(labels)

sepal_width_ew_binning = pd.cut(PETAL_LENGTH_SERIES, amount_of_binning, True, labels)
labelled_sepal_width_ew_binning = sepal_width_ew_binning.value_counts()
interval_sepal_width_ew_binning = pd.cut(PETAL_LENGTH_SERIES, amount_of_binning, True).value_counts()

# %%
# dataframe of petal-length and sepal category
pd.concat((PETAL_LENGTH_SERIES, sepal_width_ew_binning), axis=1)
# Out:
#      petal.length sepal.length
# 0             1.4            A
# 1             1.4            A
# 2             1.3            A
# 3             1.5            A
# 4             1.4            A
# ..            ...          ...
# 145           5.2            B
# 146           5.0            B
# 147           5.2            B
# 148           5.4            B
# 149           5.1            A
#
# [150 rows x 2 columns]

# %%
# equal-width intervals binning with label
labelled_sepal_width_ew_binning
# Out:
# A    89
# B    61
# Name: sepal.length, dtype: int64

# %%
# equal-width intervals without label
interval_sepal_width_ew_binning
# Out:
# (-0.003, 1.5]    89
# (1.5, 3.0]       61
# Name: sepal.length, dtype: int64

# %%
# equal-width intervals

labels = ["A", "B"]
amount_of_binning = len(labels)

sepal_width_ew_binning = pd.cut(PETAL_WIDTH_SERIES, amount_of_binning, True, labels)
labelled_sepal_width_ew_binning = sepal_width_ew_binning.value_counts()
interval_sepal_width_ew_binning = pd.cut(PETAL_WIDTH_SERIES, amount_of_binning, True).value_counts()

# %%
# dataframe of petal-width and sepal category
pd.concat((PETAL_WIDTH_SERIES, sepal_width_ew_binning), axis=1)
# Out:
#      petal.width sepal.length
# 0            0.2            A
# 1            0.2            A
# 2            0.2            A
# 3            0.2            A
# 4            0.2            A
# ..           ...          ...
# 145          2.3            B
# 146          1.9            B
# 147          2.0            B
# 148          2.3            B
# 149          1.8            A
#
# [150 rows x 2 columns]

# %%
# equal-width intervals binning with label
labelled_sepal_width_ew_binning
# Out:
# A    89
# B    61
# Name: sepal.length, dtype: int64

# %%
# equal-width intervals without label
interval_sepal_width_ew_binning
# Out:
# (-0.003, 1.5]    89
# (1.5, 3.0]       61
# Name: sepal.length, dtype: int64

# %% [markdown]
# ## Equel Frequensy

# %%
import pandas as pd
import numpy as np

# %%
# membaca dataset
dt_iris = pd.read_csv("https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv")
print(dt_iris)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
dt_iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
# CONSTAN SERIES
DATA_SEPAL_LENGTH = dt_iris["sepal.length"]
DATA_SEPAL_WIDTH = dt_iris["sepal.width"]
DATA_PETAL_LENGTH = dt_iris["petal.length"]
DATA_PETAL_WIDTH = dt_iris["petal.width"]

# %%
def qcut(col, k):
    intervals = pd.qcut(dt_iris[col], k).value_counts().index.to_list()
    return [[interval.left, interval.right] for interval in intervals]

# %%
interval_sepal_length = qcut("sepal.length", 5)
interval_sepal_width = qcut("sepal.width", 5)
interval_petal_length = qcut("petal.length", 5)
interval_petal_width = qcut("petal.width", 5)

print("interval sepal.length :", interval_sepal_length)
print("interval sepal.width  :", interval_sepal_width)
print("interval petal.length :", interval_petal_length)
print("interval petal.width  :", interval_petal_width)
# Out:
# interval sepal.length : [[5.0, 5.6], [4.2989999999999995, 5.0], [5.6, 6.1], [6.52, 7.9], [6.1, 6.52]]
# interval sepal.width  : [[2.7, 3.0], [1.999, 2.7], [3.1, 3.4], [3.4, 4.4], [3.0, 3.1]]
# interval petal.length : [[0.999, 1.5], [4.64, 5.32], [5.32, 6.9], [3.9, 4.64], [1.5, 3.9]]
# interval petal.width  : [[1.16, 1.5], [0.099, 0.2], [1.9, 2.5], [0.2, 1.16], [1.5, 1.9]]

# %%
def equalfreq(list_interval, col):
    # mendapatkan panjang interval
    length = len(list_interval)

    # mengurutkan interval
    sort_interval = np.sort(list_interval, axis=0)
    # mendapatkan Category dari interval
    categories = np.array([chr(65+i) for i in range(length)])[:, None]
    # combine into interval data
    intervals = np.hstack((sort_interval, categories))

    newCol = []
    for i, row in dt_iris.iterrows():
        data = row[col]
        for interval in intervals:
            if data >= interval[0].astype(float) and data <= interval[1].astype(float):
                newCol.append(interval[2])
                break

    return np.array(newCol, dtype=str)

# %%
dt_iris["sepal.length"] = equalfreq(interval_sepal_length, "sepal.length")
dt_iris["sepal.width"] = equalfreq(interval_sepal_width, "sepal.width")
dt_iris["petal.length"] = equalfreq(interval_petal_length, "petal.length")
dt_iris["petal.width"] = equalfreq(interval_petal_width, "petal.width")

# %%
dt_iris
# Out:
#     sepal.length sepal.width petal.length petal.width    variety
# 0              B           E            A           A     Setosa
# 1              A           B            A           A     Setosa
# 2              A           D            A           A     Setosa
# 3              A           C            A           A     Setosa
# 4              A           E            A           A     Setosa
# ..           ...         ...          ...         ...        ...
# 145            E           B            D           E  Virginica
# 146            D           A            D           D  Virginica
# 147            D           B            D           E  Virginica
# 148            D           D            E           E  Virginica
# 149            C           B            D           D  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Enthropy

# %%
# membaca dataset
dt_iris = pd.read_csv("https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv")
print(dt_iris)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
sample = dt_iris[["sepal.length"]]
sample.describe()
# Out:
#        sepal.length
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000

# %%
# import library
import pandas as pd
import numpy as np
import math
from sklearn import datasets

# %% [markdown]
# Membuat category random untuk semua data

# %%
np.random.seed(0)
sample["category"] = np.where(np.random.choice(2, sample.shape[0]) < 1, "A", "B" )
sample
sample.shape[0]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 150

# %% [markdown]
# Membut fungsi getOverollCategory digunakan untuk menghitung data keseluruhan yang nantinya digunakan untuk menghitung entropy

# %%
def getOverollCategory(col):
    group = sample.loc[:, :].groupby("category").count()
    a = group.loc["A", col]
    b = group.loc["B", col]
    print(a,b, group)
    return (a, b, a+b)

# %% [markdown]
# Fungsi splitter digunakan untuk membuat split antara value yang telah di tentukan lalu mengembalikan data yang telah di pisahkan

# %%
def splitter(value:float, col:str)->tuple:
    # get data less and greater from value
    less = sample[sample[col] <= value]
    greater = sample[sample[col] > value]

    # calculate into category for each data
    less_group = less.loc[:, :].groupby("category").count()
    print(less_group)
    greater_group = greater.loc[:, :].groupby("category").count()

    # get value based on category
    less_category_A = less_group.loc["A", col]
    print(less_category_A)

    less_category_B = less_group.loc["B", col]
    greater_category_A = greater_group.loc["A", col]
    greater_category_B = greater_group.loc["B", col]

    return (
        [less_category_A, less_category_B, less_category_A + less_category_B],
        [greater_category_A, greater_category_B, greater_category_A + greater_category_B]
    )

# %% [markdown]
# Buat Fungsi entropy untuk mencari nilai entropy

# %%
def entropy(d):
    r1 = (d[0] / d[2]) * np.log2(d[0] / d[2])
    r2 = (d[1] / d[2]) * np.log2(d[1] / d[2])
    return np.sum([r1, r2]) * -1

# %% [markdown]
# Membuat fungsi info dan gain

# %%
def info(d):
    r1 = (d[0][2] / sample.shape[0]) * entropy(d[0])
    r2 = (d[1][2] / sample.shape[0]) * entropy(d[1])
    return r1 + r2

# %% [markdown]
# Fungsi gain untuk menghitung selsih antara entropy awal dengan yang baru

# %%
def gain(Einitial, Enew):
    return Einitial - Enew

# %% [markdown]
# Membuat Dinitial

# %%
D = getOverollCategory("sepal.length")
entropy_d = entropy(D)
print(D)
print(entropy_d)
# Out:
# 68 82           sepal.length
# category
# A                   68
# B                   82
# (68, 82, 150)
# 0.993707106604508

# %% [markdown]
# Melakukan beberapa tes split untuk mencri informasi yang terbaik

# %% [markdown]
# *Split 1: 4.4*

# %%
split1 = splitter(4.4, "sepal.length")
info_split1 = info(split1)
gain(entropy_d, info_split1)
# Out:
#           sepal.length
# category
# A                    1
# B                    3
# 1
# 0.003488151753460178

# %% [markdown]
# *split 2: 5.5*

# %%
split2 = splitter(5.5, "sepal.length")
info_split2 = info(split2)
gain(entropy_d, info_split2)
# Out:
#           sepal.length
# category
# A                   22
# B                   37
# 22
# 0.012302155146638905

# %% [markdown]
# *split 3: 7.0*

# %%
split3 = splitter(7.0, "sepal.length")
info_split3 = info(split3)
gain(entropy_d, info_split3)
# Out:
#           sepal.length
# category
# A                   62
# B                   76
# 62
# 0.0005490214732508658

# %% [markdown]
# Dari keseluruhan split yang telah di hitung. maka split terbaik adalah split 3 yang memberikan keuntungan informasi sebesar 0.0005490214732508658
